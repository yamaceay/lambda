# %% [markdown]
# * Recall the Generation Lemma (2.10.7) for λ→. Try to write out its counterpart for λ2 (It is only mentioned in Lemma 3.6.4).
#     * Appl2: If $\Gamma \vdash MN : \sigma$, then there exists a type $A: *$ with $\sigma \equiv A[\alpha := N]$, so that $\Gamma \vdash M : \Pi \alpha : * . A$ and $\Gamma \vdash N : *$ is concluded.
#     * Abst2: If $\Gamma \vdash \lambda \alpha : * . M : \sigma$, then there exists a type $\tau : *$ with $\sigma \equiv \Pi \alpha : * . \tau$, so that $\Gamma, \alpha : * \vdash M : \tau$.
# * Clarify the role of proper constructors for yourself while reading p 87. Why can they not be inhabited?
#     * Take for example $\lambda \alpha : * . \alpha : * \to *$ which is located in level 2. Then, there is no term $M$ such that $M : \lambda \alpha : * . \alpha$.
# * Take the time to look back to the treatment of contexts in λ→ and λ2, while reading through the 3 paragraphs after Definition 4.2.1 ... also compare to the exercise 3.19, which we discussed in A6/S6.
#     * Permissibility of types have to be defined using derivation rules, since the types are a bit more complex.
# * In Definition 4.2.2, note the new interpretation of x .! What does x∈Γ formally mean? Consider the comment on "freshness". Does it refer to just the free occurrences or also to the bound/binding ones?
#     * Just the free occurrences. All type and term variables should be different.
# Carefully check the derivation for (?1) on p 91.
# * Remark 4.6.1 ...
# * Remark 4.7.2 !!!
# * Clarity the difference between Subject Reduction and Type Reduction/Convergence for yourself.
# * Make sure you read the second and third paragraph of §4.10 ...
# * Decide for yourself, which of the Exercises 4.2-4.5 you want to do by yourself.
#     4.2.a
#     * (-3) $\vdash * : \square$ (sort)
#     * (-2) $\vdash * \to * : \square$ (form) on (-3) and (-3)
#     * (-1) $\vdash * : \square$ (sort)
#     * (0) $\vdash (* \to *) \to * : \square$ (form) on (-2) and (-1)
#
#     4.2.b
#     * (-8) $\vdash * : \square$ (sort)
#     * (-7) $\alpha : * \vdash \alpha : *$ (var) on (-8)
#     * (-6) $\vdash * : \square$ (sort)
#     * (-5) $\alpha : * \vdash * : \square$ (weak) on (-6) and (-6)
#     * (-4) $\alpha : *, \beta : * \vdash \alpha : *$ (weak) on (-7) and (-6)
#     * (-3) $\alpha : *, \beta : * \vdash \beta : *$ (var) on (-5)
#     * (-2) $\alpha : *, \beta : * \vdash \alpha \to \beta : *$ (form) on (-4) and (-3)
#     * (-1) $\alpha : *, \beta : * \vdash \alpha : *$ (weak) on (-7) and (-6)
#     * (0) $\alpha : *, \beta : * \vdash (\alpha \to \beta) \to \alpha : *$ (form) on (-2) and (-1)
#
#     4.3.a
#     * (-12) $\vdash * : \square$ (sort)
#     * (-11) $\alpha : * \vdash \alpha : *$ (var) on (-12)
#     * (-10) $\alpha : * \vdash * : \square$ (weak) on (-12) and (-12)
#     * (-9) $\alpha, \beta : * \vdash \beta : *$ (var) on (-10)
#     * (-8) $\alpha, \beta : * \vdash \alpha : *$ (weak) on (-11) and (-10)
#     * (-7) $\alpha, \beta : * \vdash \alpha \to \beta : *$ (form) on (-9) and (-8)
#     * (-6) $\alpha, \beta : *, x : \alpha \vdash \alpha : *$ (weak) on (-8) and (-8)
#     * (-5) $\alpha, \beta : *, x : \alpha \vdash \beta : *$ (weak) on (-9) and (-8)
#     * (-4) $\alpha, \beta : *, y : \alpha \to \beta \vdash \alpha : *$ (weak) on (-8) and (-7)
#     * (-3) $\alpha, \beta : *, x : \alpha \vdash \alpha \to \beta : *$ (form) on (-6) and (-5)
#     * (-2) $\alpha, \beta : *, x : \alpha, y : \alpha \to \beta \vdash x : \alpha$ (var) on (-4)
#     * (-1) $\alpha, \beta : *, x : \alpha, y : \alpha \to \beta \vdash y : \alpha \to \beta$ (var) on (-3)
#     * (0) $\alpha, \beta : * . x : \alpha, y : \alpha \to \beta \vdash yx : \beta$ (appl) on (-2) and (-1)
#
#     4.3.b
#
#     * (-14) $\vdash * : \square$ (sort)
#     * (-13) $\alpha : * \vdash * : \square$ (weak) on (-14) and (-14)
#     * (-12) $\alpha : * \vdash \alpha : *$ (var) on (-14)
#     * (-11) $\alpha, \beta : * \vdash \beta : *$ (var) on (-13)
#     * (-10) $\alpha, \beta : * \vdash \alpha : *$ (weak) on (-13) and (-12)
#     * (-9) $\alpha, \beta : *, x : \alpha \vdash \beta : *$ (weak) on (-11) and (-10)
#     * (-8) $\alpha, \beta : *, x : \alpha \vdash \alpha : *$ (weak) on (-10) and (-10)
#     * (-7) $\alpha, \beta : *, x : \alpha \vdash \alpha \to \beta : *$ (form) on (-9) and (-8)
#     * (-6) $\alpha, \beta : *, x : \alpha, y : \alpha \to \beta \vdash \beta : *$ (weak) on (-9) and (-7)
#     * (-5) $\alpha, \beta : *, x : \alpha, y : \alpha \to \beta \vdash \alpha : *$ (weak) on (-8) and (-7)
#     * (-4) $\alpha, \beta : *, x : \alpha, y : \alpha \to \beta \vdash y x : \beta$ (4.3.a)
#     * (-3) $\alpha, \beta : *, x : \alpha, y : \alpha \to \beta \vdash \beta \to \alpha : *$ (form) on (-6) and (-5)
#     * (-2) $\alpha, \beta : *, x : \alpha, y : \alpha \to \beta, z : \beta \to \alpha \vdash z : \beta \to \alpha$ (var) on (-3)
#     * (-1) $\alpha, \beta : *, x : \alpha, y : \alpha \to \beta, z : \beta \to \alpha \vdash y x : \beta$ (weak) on (-4) and (-3)
#     * (0) $\alpha, \beta : *, x : \alpha, y : \alpha \to \beta, z : \beta \to \alpha \vdash z (y x) : \alpha$ (appl) on (-2) and (-1)
#
#     4.4.a
#     * (-7) $\vdash * : \square$ (sort)
#     * (-6) $\alpha : * \vdash * : \square$ (weak) on (-7) and (-7)
#     * (-5) $\alpha : * \vdash \alpha : *$ (var) on (-7)
#     * (-4) $\alpha : * \vdash * \to * : \square$ (form) on (-6) and (-6)
#     * (-3) $\alpha : *, \beta : * \to * \vdash \alpha : *$ (weak) on (-5) and (-4)
#     * (-2) $\alpha : *, \beta : * \to * \vdash \beta : * \to *$ (var) on (-4)
#     * (-1) $\alpha : *, \beta : * \to * \vdash \beta \alpha : *$ (appl2) on (-3) and (-2)
#     * (0) $\alpha : *, \beta : * \to * \vdash \beta(\beta \alpha) : *$ (appl2) on (-2) and (-1)
#
#     4.4.b
#     * (-4) $\alpha : *, \beta : * \to * \vdash \beta (\beta \alpha) : *$ (4.4.a: 0)
#     * (-3) $\alpha : *, \beta : * \to * \vdash \alpha : *$ (4.4.a: -3)
#     * (-2) $\alpha : *, \beta : * \to *, y : \alpha \vdash \beta (\beta \alpha) : *$ (weak) on (-4) and (-3)
#     * (-1) $\alpha : *, \beta : * \to *, x : \beta(\beta \alpha), y : \alpha \vdash x : \beta (\beta \alpha)$ (var) on (-2)
#     * (0) $\alpha : *, \beta : * \to *, x : \beta(\beta \alpha) \vdash \lambda y : \alpha . x : \alpha \to \beta (\beta \alpha)$ (abst) on (-1)
#
#     4.4.c
#     * (-6) $\alpha : *, \beta : * \to * \vdash \beta (\beta \alpha) : *$ (4.4.a: 0)
#     * (-5) $\vdash *: \square$ (sort)
#     * (-4) $\vdash * \to * : \square$ (form) on (-5) and (-5)
#     * (-3) $\vdash (* \to *) \to *: \square$ (form) on (-5) and (-4)
#     * (-2) $\alpha : * \vdash \lambda \beta : * \to * . \beta (\beta \alpha) : (* \to *) \to *$ (abst2) on (-6) and (-3)
#     * (-1) $\vdash * \to (* \to *) \to *: \square$ (form) on (-5) and (-3)
#     * (0) $\vdash \lambda \alpha : * . \lambda \beta : * \to * . \beta (\beta \alpha) : * \to (* \to *) \to *$ (abst2) on (-2) and (-1)
#
#     4.4.d
#     * (-6) $\vdash \text{nat} : *$ (given)
#     * (-5) $\vdash \lambda \alpha : * . \lambda \beta : * \to * . \beta (\beta \alpha) : * \to (* \to *) \to *$ (4.4.c: 0)
#     * (-4) $\vdash * : \square$ (sort)
#     * (-3) $\gamma : * \vdash \gamma : *$ (var) on (-4)
#     * (-2) $\vdash (\lambda \alpha : * . \lambda \beta : * \to * . \beta (\beta \alpha)) \text{nat} : (* \to *) \to *$ (appl2) on (-6) and (-5)
#     * (-1) $\vdash \lambda \gamma : * . \gamma : * \to *$ (abst2) on (-3)
#     * (0) $\vdash (\lambda \alpha : * . \lambda \beta : * \to * . \beta (\beta \alpha)) \text{nat} (\lambda \gamma : * . \gamma) : *$ (appl2) on (-2) and (-1)
#
#     4.5
#     * (-7) $\vdash * : \square$ (sort)
#     * (-6) $\alpha : * \vdash \alpha : *$ (var) on (-7)
#     * (-5) $\alpha : *, y : \alpha \vdash \alpha : *$ (weak) on (-6) and (-6)
#     * (-4) $\alpha : *, x : \alpha \vdash \alpha : *$ (weak) on (-6) and (-6)
#     * (-3) $\alpha : *, x : \alpha, y : \alpha \vdash x : \alpha$ (var) on (-5)
#     * (-2) $\alpha : *, x : \alpha \vdash \alpha \to \alpha : *$ (form) on (-4) and (-4)
#     * (-1) $\alpha : *, x : \alpha \vdash \lambda y : \alpha . x : \alpha \to \alpha$ (abst) on (-3)
#     * (0) $\alpha : *, x : \alpha \vdash \lambda y : \alpha . x : (\lambda \beta : * . \beta \to \beta) \alpha$ (conv) on (-2) and (-1)
# * Try to write out the Generation Lemma for λω–– .
#
# (appl2) If $\Gamma \vdash MN : B : s$ with $s \in \{*, \square\}$, then $\exists A : s$, so that $\Gamma \vdash M : A \to B$ and $\Gamma \vdash N : A$
#
# (abst2) If $\Gamma \vdash \lambda x : A . M : B : s$ with $s \in \{*, \square\}$, then $\exists C : s$ with $B \equiv A \to C$, so that $\Gamma, x : A \vdash M : B$ and $\Gamma \vdash A \to C : s$.
