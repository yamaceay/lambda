# %% [markdown]
# * In Remark 6.2.3, rethink our observation of last session concerning the "coincidence" between the rules in Figures 4.1 and 6.4.
#     * Pi-types are just generalizations of arrow types. Arrow types can however be used if we know that the type does not depend on the argument.
#
# * On p 128, the authors state w.r.t. Definition 2.10.1(!) on p 54: "Many of theses changes in definition are straightforward and therefore we do not spell them out." So, please spell them out for yourselves.
#     * Free Variables Lemma
#     * Substitution Lemma
#     * Generation Lemma
#     * Weakening Lemma
#     * Thinning Lemma
#     * Church-Rosser Theorem
#     * Strong Normalization Theorem
#     * Confluence Theorem
#     * Uniqueness of Types Theorem
#     * Subject Reduction Theorem
#
# * Recall Definition 3.4.4 on p 75 for this task. Also give a definition for free variables of expressions. And define context "inclusion", too, please (as mentioned right after Lemma 6.3.5).
#     * $FV(A) = \{\}$
#     * $FV(x) = \{x\}$
#     * $FV(\lambda x : A . M) = FV(A) \cup (FV(M) \setminus \{x\})$
#     * $FV(\Pi x : A . M) = FV(A) \cup (FV(M) \setminus \{x\})$
#     * $FV(MN) = FV(M) \cup FV(N)$
#
# * Compare the Generation Lemma 6.3.6 to our previous attempts for λω in S7. Think about how to prove it.
#     * $\Gamma \vdash x : C \implies \exists s \in \{*, \square\}, B . B =_\beta C, \Gamma \vdash B : s, x : B \in \Gamma$ (conv)
#
#     * $\Gamma \vdash MN : C \implies \exists A, B . \Gamma \vdash M : \Pi x : A . B, \Gamma \vdash N : A, C =_\beta B[x := N]$ (appl)
#
#     * $\Gamma \vdash \lambda x : A . b : C \implies \exists s \in \{*, \square\}, B . \Gamma \vdash \Pi x : A . B : s, \Gamma, x : A \vdash b : B, C =_\beta \Pi x : A . B$ (abst)
#
#     * $\Gamma \vdash \Pi x : A . B : C \implies \exists s_1, s_2 \in \{*, \square\}. \Gamma \vdash A : s_1, \Gamma, x : A \vdash B : s_2, C =_\beta s_2$ (abst_2)
#
# * Carefully read the paragraph after Lemma 6.3.10 and come up with a definition for substitution on contexts, as it is required according to the end of that paragraph.
#     * $\Gamma''[x := N] = (v : A[x := N] \mid v : A \in \Gamma)$
#
# * Do Exercises 6.1-3. (If time permits, we will look at the solutions to Exercises 6.4, 6.6, 6.8 in class.)
#     * Exercise 6.1.
#
#         * $\bot \equiv \Pi \alpha : * . \alpha$ is legal in $\lambda C$
#             * Typable: $\Pi \alpha : * . \alpha : \square$
#         * $\bot \to \bot$ is legal as well
#             * Typable: $\Pi \alpha : * . \alpha \to \Pi \alpha : * . \alpha : \square$
#         * $\bot$ not in $\lambda 2$ and $\lambda P$, because $\Pi \alpha : * . \alpha$ is not typable in $\lambda 2$ and $\lambda P$
#         * $\bot \to \bot$ not in $\lambda 2$ and $\lambda P$, because $\Pi \alpha : * . \alpha \to \Pi \alpha : * . \alpha$ is not typable in $\lambda 2$ and $\lambda P$
#
#     * Exercise 6.2.
#
#         * (-34) $S : *, P : S \to *, A : *, z : \Pi x : S . (A \to P x), l : A, y : S \vdash z : \Pi x : S . (A \to P x)$ (var)
#
#         * (-33) $S : *, P : S \to *, A : *, z : \Pi x : S . (A \to P x), l : A, y : S \vdash y : S$ (var)
#
#         * (-32) $S : *, P : S \to *, A : *, z : \Pi x : S . (A \to P x), l : A, y : S \vdash zy : A \to Py$ (appl) on (-34) and (-33)
#
#         * (-31) $S : *, P : S \to *, A : *, z : \Pi x : S . (A \to P x), l : A, y : S \vdash l : A$ (var)
#
#         * (-30) $S : *, P : S \to *, A : *, z : \Pi x : S . (A \to P x), l : A, y : S \vdash P : s \to *$ (var)
#
#         * (-29) $S : *, P : S \to *, A : *, z : \Pi x : S . (A \to P x), l : A, y : S \vdash y : S$ (var)
#
#         * (-28) $S : *, P : S \to *, A : *, z : \Pi x : S . (A \to P x), l : A, y : S \vdash P : S \to *$ (var)
#
#         * (-27) $S : *, P : S \to *, A : *, z : \Pi x : S . (A \to P x), l : A, y : S \vdash y : S$ (var)
#
#         * (-26) $S : *, P : S \to *, A : *, x : S, l : A \vdash P : S \to *$ (var)
#
#         * (-25) $S : *, P : S \to *, A : *, x : S, l : A \vdash x : S$ (var)
#
#         * (-24) $S : *, P : S \to *, A : *, z : \Pi x : S . (A \to P x), l : A, y : S \vdash P : S \to *$ (var)
#
#         * (-23) $S : *, P : S \to *, A : *, z : \Pi x : S . (A \to P x), l : A, y : S \vdash y : S$ (var)
#
#         * (-22) $S : *, P : S \to *, A : *, z : \Pi x : S . (A \to P x), l : A \vdash S : *$ (var)
#
#         * (-21) $S : *, P : S \to *, A : *, z : \Pi x : S . (A \to P x), l : A, y : S \vdash Py : *$ (appl) on (-30) and (-29)
#
#         * (-20) $S : *, P : S \to *, A : *, z : \Pi x : S . (A \to P x), l : A \vdash S : *$ (var)
#
#         * (-19) $S : *, P : S \to *, A : *, z : \Pi x : S . (A \to P x), l : A, y : S \vdash Py : *$ (appl) on (-28) and (-27)
#
#         * (-18) $S : *, P : S \to *, A : *, x : S \vdash A : *$ (var)
#
#         * (-17) $S : *, P : S \to *, A : *, x : S, l : A \vdash P x : *$ (appl) on (-26) and (-25)
#
#         * (-16) $S : *, P : S \to *, A : *, z : \Pi x : S . (A \to P x), l : A \vdash S : *$ (var)
#
#         * (-15) $S : *, P : S \to *, A : *, z : \Pi x : S . (A \to P x), l : A, y : S \vdash Py : *$ (appl) on (-24) and (-23)
#
#         * (-14) $S : *, P : S \to *, A : *, z : \Pi x : S . (A \to P x), l : A, y : S \vdash zyl : Py$ (appl) on (-32) and (-31)
#
#         * (-13) $S : *, P : S \to *, A : *, z : \Pi x : S . (A \to P x), l : A \vdash \Pi y : S . Py : *$ (form) on (-22) and (-21)
#
#         * (-12) $S : *, P : S \to *, A : *, z : \Pi x : S . (A \to P x) \vdash A  : *$ (var)
#
#         * (-11) $S : *, P : S \to *, A : *, z : \Pi x : S . (A \to P x), l : A \vdash \Pi y : S . Py : *$ (form) on (-20) and (-19)
#
#         * (-10) $S : *, P : S \to *, A : * \vdash S : *$ (var)
#
#         * (-9) $S : *, P : S \to *, A : *, x : S \vdash A \to P x : *$ (form) on (-18) and (-17)
#
#         * (-8) $S : *, P : S \to *, A : *, z : \Pi x : S . (A \to P x) \vdash A : *$ (var)
#
#         * (-7) $S : *, P : S \to *, A : *, z : \Pi x : S . (A \to P x), l : A \vdash \Pi y : S . Py : *$ (form) on (-16) and (-15)
#
#         * (-6) $S : *, P : S \to *, A : *, z : \Pi x : S . (A \to P x), l : A \vdash \lambda y : S . zyl : \Pi y : S . Py$ (abst) on (-14) and (-13)
#
#         * (-5) $S : *, P : S \to *, A : *, z : \Pi x : S . (A \to P x) \vdash A \to \Pi y : S . Py : *$ (form) on (-12) and (-11)
#
#         * (-4) $S : *, P : S \to *, A : * \vdash \Pi x : S . (A \to P x) : *$ (form) on (-10) and (-9)
#
#         * (-3) $S : *, P : S \to *, A : *, z : \Pi x : S . (A \to P x) \vdash A \to \Pi y : S . Py : *$ (form) on (-8) and (-7)
#
#         * (-2) $S : *, P : S \to *, A : *, z : \Pi x : S . (A \to P x) \vdash \lambda l : A . \lambda y : S . zyl : A \to \Pi y : S . Py$ (abst) on (-6) and (-5)
#
#         * (-1) $S : *, P : S \to *, A : * \vdash (\Pi x : S . (A \to P x)) \to A \to \Pi y : S . Py : *$ (form) on (-4) and (-3)
#
#         * (0) $S : *, P : S \to *, A : * \vdash \lambda z : (\Pi x : S . (A \to P x)) . \lambda l : A . \lambda y : S . zyl : (\Pi x : S . (A \to P x)) \to A \to \Pi y : S . Py$ (abst) on (-2) and (-1)
#
#     * Exercise 6.3.
#
#         * (-10) $S : *, P : S \to *, x : S, u : Px \vdash * : \square$ (sort)
#
#         * (-9) $S : *, P : S \to *, x : S, u : Px, \alpha : * \vdash * : \square$ (sort)
#
#         * (-8) $S : *, P : S \to *, x : S \vdash P : S \to *$ (var)
#
#         * (-7) $S : *, P : S \to *, x : S \vdash x : S$ (var)
#
#         * (-6) $S : *, P : S \to *, x : S \vdash Px : *$ (appl) on (-8) and (-7)
#
#         * (-5) $S : *, P : S \to *, x : S, u : Px \vdash \bot : \square$ (form) on (-10) and (-9)
#
#         * (-4) $S : *, P : S \to * \vdash S : *$ (var)
#
#         * (-3) $S : *, P : S \to *, x : S \vdash * : \square$ (sort)
#
#         * (-2) $S : *, P : S \to *, x : S \vdash Px \to \bot : *$ (form) on (-6) and (-5)
#
#         * (-1) $S : *, P : S \to * \vdash S \to * : \square$ (form) on (-4) and (-3)
#
#         * (0) $S : *, P : S \to * \vdash \lambda x : S . (Px \to \bot) : S \to *$ (abst) on (-2) and (-1)
#
#     * Exercise 6.4.a.
#
#         * (-26) $S : *, Q : S \to S \to *, y : S, x : S, v : Q x y \vdash y : S$ (var)
#
#         * (-25) $S : *, Q : S \to S \to *, y : S, x : S, v : Q x y \vdash Q : S \to * \to *$ (var)
#
#         * (-24) $S : *, Q : S \to S \to *, y : S, x : S \vdash x : S$ (var)
#
#         * (-23) $S : *, Q : S \to S \to *, y : S, x : S \vdash Q : S \to S \to *$ (var)
#
#         * (-22) $S : *, Q : S \to S \to *, y : S, x : S, v : Q x y \vdash x : S$ (var)
#
#         * (-21) $S : *, Q : S \to S \to *, y : S, x : S, v : Q x y \vdash Q y : S \to *$ (appl) on (-26) and (-25)
#
#         * (-20) $S : *, Q : S \to S \to *, y : S, x : S \vdash y : S$ (var)
#
#         * (-19) $S : *, Q : S \to S \to *, y : S, x : S \vdash Q x : S \to *$ (appl) on (-24) and (-23)
#
#         * (-18) $S : *, Q : S \to S \to *, y : S, x : S, v : Q x y \vdash Q y x : *$ (appl) on (-22) and (-21)
#
#         * (-17) $S : *, Q : S \to S \to *, y : S, x : S, v : Q x y, w : Q y x \vdash \bot : \square$ (prev)
#
#         * (-16) $S : *, Q : S \to S \to *, k : \Pi y : S . (\Pi x : S . (Q x y \to (Q y x \to \bot))), z : S \vdash z : S$ (var)
#
#         * (-15) $S : *, Q : S \to S \to *, k : \Pi y : S . (\Pi x : S . (Q x y \to (Q y x \to \bot))), z : S \vdash Q : S \to S \to *$ (var)
#
#         * (-14) $S : *, Q : S \to S \to *, y : S, x : S \vdash Q x y : *$ (appl) on (-20) and (-19)
#
#         * (-13) $S : *, Q : S \to S \to *, y : S, x : S, v : Q x y \vdash Q y x \to \bot : *$ (form) on (-18) and (-17)
#
#         * (-12) $S : *, Q : S \to S \to *, k : \Pi y : S . (\Pi x : S . (Q x y \to (Q y x \to \bot))), z : S \vdash z : S$ (var)
#
#         * (-11) $S : *, Q : S \to S \to *, k : \Pi y : S . (\Pi x : S . (Q x y \to (Q y x \to \bot))), z : S \vdash Q z : S \to *$ (appl) on (-16) and (-15)
#
#         * (-10) $S : *, Q : S \to S \to *, y : S \vdash S : *$ (var)
#
#         * (-9) $S : *, Q : S \to S \to *, y : S, x : S \vdash Q x y \to (Q y x \to \bot) : *$ (form) on (-14) and (-13)
#
#         * (-8) $S : *, Q : S \to S \to *, k : \Pi y : S . (\Pi x : S . (Q x y \to (Q y x \to \bot))), z : S \vdash Q z z : *$ (appl) on (-12) and (-11)
#
#         * (-7) $S : *, Q : S \to S \to *, k : \Pi y : S . (\Pi x : S . (Q x y \to (Q y x \to \bot))), z : S, u : Q z z \vdash \bot \equiv k z z u u : *$
#
#         * (-6) $S : *, Q : S \to S \to * \vdash S : *$ (var)
#
#         * (-5) $S : *, Q : S \to S \to *, y : S \vdash \Pi x : S . (Q x y \to (Q y x \to \bot)) : *$ (form) on (-10) and (-9)
#
#         * (-4) $S : *, Q : S \to S \to *, k : \Pi y : S . (\Pi x : S . (Q x y \to (Q y x \to \bot))) \vdash S : *$ (var)
#
#         * (-3) $S : *, Q : S \to S \to *, k : \Pi y : S . (\Pi x : S . (Q x y \to (Q y x \to \bot))), z : S \vdash Q z z \to \bot : *$ (form) on (-8) and (-7)
#
#         * (-2) $S : *, Q : S \to S \to * \vdash \Pi y : S . (\Pi x : S . (Q x y \to (Q y x \to \bot))) : *$ (form) on (-6) and (-5)
#
#         * (-1) $S : *, Q : S \to S \to *, k : \Pi y : S . (\Pi x : S . (Q x y \to (Q y x \to \bot))) \vdash \Pi z : S . (Q z z \to \bot) : *$ (form) on (-4) and (-3)
#
#         * (0) $S : *, Q : S \to S \to * \vdash (\Pi y : S . (\Pi x : S . (Q x y \to (Q y x \to \bot)))) \to (\Pi z : S . (Q z z \to \bot)) : *$ (form) on (-2) and (-1)
#
#     * Exercise 6.4.b.
#
#         * (-12) $S : *, Q : S \to S \to *, k : \Pi x, y : S . (Q x y \to (Q y x \to \bot)), z : S \vdash Q : S \to S \to *$ (var)
#
#         * (-11) $S : *, Q : S \to S \to *, k : \Pi x, y : S . (Q x y \to (Q y x \to \bot)), z : S \vdash z : S$ (var)
#
#         * (-10) $S : *, Q : S \to S \to *, k : \Pi x, y : S . (Q x y \to (Q y x \to \bot)), z : S, u : Q z z \vdash \bot \equiv k z z u u : *$
#
#         * (-9) $S : *, Q : S \to S \to *, k : \Pi x, y : S . (Q x y \to (Q y x \to \bot)), z : S \vdash Q z z : *$ (appl) on (-12) and (-11)
#
#         * (-8) $S : *, Q : S \to S \to *, k : \Pi x, y : S . (Q x y \to (Q y x \to \bot)), z : S \vdash Q z z \to \bot : *$ (form) on (-10) and (-9)
#
#         * (-7) $S : *, Q : S \to S \to *, k : \Pi x, y : S . (Q x y \to (Q y x \to \bot)), z : S, u : Q z z \vdash \bot : \square$ (prev)
#
#         * (-6) $S : *, Q : S \to S \to *, k : \Pi x, y : S . (Q x y \to (Q y x \to \bot)), z : S \vdash Q z z \to \bot : *$ (form) on (-10) and (-9)
#
#         * (-5) $S : *, Q : S \to S \to *, k : \Pi x, y : S . (Q x y \to (Q y x \to \bot)) \vdash S : *$ (var)
#
#         * (-4) $S : *, Q : S \to S \to *, k : \Pi x, y : S . (Q x y \to (Q y x \to \bot)), z : S \vdash ? : Q z z \to \bot$ (abst) on (-8) and (-7)
#
#         * (-3) $S : *, Q : S \to S \to *, k : \Pi x, y : S . (Q x y \to (Q y x \to \bot)) \vdash \Pi z : S . (Q z z \to \bot) : *$ (form) on (-6) and (-5)
#
#         * (-2) $S : *, Q : S \to S \to *, k : \Pi x, y : S . (Q x y \to (Q y x \to \bot)) \vdash ? : \Pi z : S . (Q z z \to \bot)$ (abst) on (-4) and (-3)
#
#         * (-1) $S : *, Q : S \to S \to * \vdash (\Pi x, y : S . (Q x y \to (Q y x \to \bot))) \to (\Pi z : S . (Q z z \to \bot)) : *$ (prev)
#
#         * (0) $S : *, Q : S \to S \to * \vdash ? : (\Pi x, y : S . (Q x y \to (Q y x \to \bot))) \to (\Pi z : S . (Q z z \to \bot))$ (abst) on (-2) and (-1)
#
#     * Exercise 6.6
#
#         * (-20) $S : *, P : S, x : S \to * \vdash * : \square$ (sort)
#
#         * (-19) $S : *, P : S, x : S \to *, \alpha : * \vdash * : \square$ (sort)
#
#         * (-18) $S : * \vdash S : *$ (var)
#
#         * (-17) $S : *, x : S \vdash * : \square$ (sort)
#
#         * (-16) $S : *, P : S \to * \vdash S : *$ (var)
#
#         * (-15) $S : *, P : S, x : S \to * \vdash * \to * : \square$ (form) on (-20) and (-19)
#
#         * (-14) $S : * \vdash (S \to *) : \square$ (form) on (-18) and (-17)
#
#         * (-13) $S : *, P : S \to * \vdash \Pi x : S . (* \to *) : \square$ (form) on (-16) and (-15)
#
#         * (-12) $\vdash * : \square$ (sort)
#
#         * (-11) $S : * \vdash (S \to *) \to \Pi x : S . (* \to *) : \square$ (form) on (-14) and (-13)
#
#         * (-10) $S : *, P : S \to *, x : S \vdash P : S \to *$ (var)
#
#         * (-9) $S : *, P : S \to *, x : S \vdash x : S$ (var)
#
#         * (-8) $S : *, P : S \to *, x : S \vdash Px : *$ (appl) on (-10) and (-9)
#
#         * (-7) $S : *, P : S \to *, x : S, u : Px \vdash \bot : \square$ (prev)
#
#         * (-6) $S : *, P : S \to * \vdash \Pi x : S . (* \to *) : \square$ (form) on (-16) and (-15)
#
#         * (-5) $S : *, P : S \to *, x : S \vdash Px \to \bot : * \to *$ (form) on (-8) and (-7)
#
#         * (-4) $S : * \vdash (S \to *) \to \Pi x : S . (* \to *) : \square$ (form) on (-14) and (-13)
#
#         * (-3) $S : *, P : S \to * \vdash \lambda x : S . (Px \to \bot) : \Pi x : S . (* \to *)$ (abst) on (-6) and (-5)
#
#         * (-2) $\vdash * \to (S \to *) \to \Pi x : S . (* \to *) : \square$ (form) on (-12) and (-11)
#
#         * (-1) $S : * \vdash \lambda P : S \to * . \lambda x : S . (Px \to \bot) : (S \to *) \to \Pi x : S . (* \to \square)$ (abst) on (-4) and (-3)
#
#         * (0) $\vdash \lambda S : * . \lambda P : S \to * . \lambda x : S . (Px \to \bot) : * \to (S \to *) \to \Pi x : S . (* \to \square)$ (abst) on (-2) and (-1)
#
#         * $* \to (S \to *) \to \Pi x : S . (* \to \square)$
#
#     * Exercise 6.8
#
#         * (-4) $S : *, P : S \to *, z : \Pi \alpha : * . ((\Pi x : S . (P x \to \alpha)) \to \alpha) \vdash [\Pi x : S . (P x \to \bot)] \to \bot : s$
#
#         * (-3) $S : *, P : S \to *, z : \Pi \alpha : * . ((\Pi x : S . (P x \to \alpha)) \to \alpha), k : \Pi x : S . (P x \to \bot) \vdash ? : \bot$
#
#         * (-2) $S : *, P : S \to * \vdash [\Pi \alpha : * . ((\Pi x : S . (P x \to \alpha)) \to \alpha)] \to [\Pi x : S . (P x \to \bot)] \to \bot : s$ (form) on (-4) and (-3)
#
#         * (-1) $S : *, P : S \to *, z : \Pi \alpha : * . ((\Pi x : S . (P x \to \alpha)) \to \alpha) \vdash ? : [\Pi x : S . (P x \to \bot)] \to \bot$ (abst) on (-4) and (-3)
#
#         * (0) $S : *, P : S \to * \vdash ? : [\Pi \alpha : * . ((\Pi x : S . (P x \to \alpha)) \to \alpha)] \to [\Pi x : S . (P x \to \bot)] \to \bot$ (abst) on (-2) and (-1)
