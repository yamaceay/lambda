# %% [markdown]
# * Directly compare the rule sets in Figures 4.1 and 5.1. ...
#
#     * (form)
#         * $\Gamma \vdash A : s$ and $\Gamma \vdash B : s$ implies $\Gamma \vdash A \to B : s$
#         * $\Gamma \vdash A : *$ and $\Gamma, x : A \vdash B : s$ implies $\Gamma \vdash \Pi x : A . B : s$
#     * (appl)
#         * $\Gamma \vdash M : A \to B$ and $\Gamma \vdash N : A$ implies $\Gamma \vdash M N : B$
#         * $\Gamma \vdash M : \Pi x : A . B$ and $\Gamma \vdash N : A$ implies $\Gamma \vdash M N : B[x := N]$
#     * (abst)
#         * $\Gamma, x : A \vdash M : B$ and $\Gamma \vdash A \to B : s$ implies $\Gamma \vdash \lambda x : A . M : A \to B$
#         * $\Gamma, x : A \vdash M : B$ and $\Gamma \vdash \Pi x : A . B : s$ implies $\Gamma \vdash \lambda x : A . M : \Pi x : A . B$
#
#     * $\Pi$ reappears, since the terms $x$ may appear freely in type $A$.
#     * $\lambda x : A . M$ is the only possible function format given $A : *$.
#
# * Do you agree that "upgrade" and "downgrade" are properly chosen words on p 106 in (i) and (ii)?
#
#     * I think on the first sight yes. If there is a hierarchy between terms, types, kinds, super-kinds, super-super-kinds etc., we could have said that it goes upwards from terms to types.
#     * Otherwise, I disagree. This is just another extension of a cube, and they are both apples and oranges.
#
# * Notation 5.2.1 is important!
# * Carefully check the derivation in § 5.3.
# * Refresh your knowledge about functional completeness of (propositional) logic.
# * In "IV" on p 111, I have some doubts about the "string of equivalences". What about you?
# * Try to do Exercise 5.4 for yourself.
#
#     * A kind is legal, if we can derive it using $\{\}$. Sort rule clearly says that $* : \square$ holds always true. Same isn't true for $\square$, since there is no way to derive it. The contradiction relies on the set theory, where it is stated that there can be no super-set of all sets.
#
#     * Let $A, B \in S$
#         * Assume $A \implies (A \implies B)$
#             * Assume $A$
#                 * $A \implies B$ ($\implies$-elim)
#                 * $B$
#             * $A \implies B$ ($\implies$-intro)
#         * $(A \implies (A \implies B)) \implies (A \implies B)$ ($\implies$-intro)
#     * $\forall A, B \in S . (A \implies (A \implies B)) \implies (A \implies B)$ ($\forall$-intro)
#
# * Do Exercise 5.5.
#
#     * Let $A, B \in S$
#         * Assume $A$
#             * Assume $A \implies B$
#                 * $B$ ($\implies$-elim)
#             * $(A \implies B) \implies B$ ($\implies$-intro)
#         * $A \implies (A \implies B) \implies B$ ($\implies$-intro)
#     * $\forall A, B \in S . A \implies (A \implies B) \implies B$ ($\forall$-intro)
#
# * Try to do Example 5.12 ...
#
#     * $\Gamma \equiv S : *, R : S \to S \to *, u : \Pi x , y : S . R x y \to R y x, v : \Pi x , y, z : S . R x y \to R x z \to R y z$
#
#     * --- BEGIN GAMMA ---
#     * Let $S : *$
#     * Let $R : S \to S \to *$
#     * Let $u : \Pi x , y : S . R x y \to R y x$
#     * Let $v : \Pi x , y, z : S . R x y \to R x z \to R y z$
#     * --- END GAMMA ---
#
#     * (-23) $x, y : S, p : R x y \vdash u : \lambda x, y : S . R x y \to R y x$ (VAR)
#     * (-22) $x, y : S, p : R x y \vdash y : S$ (VAR)
#     * (-21) $x, y : S, p : R x y \vdash u y : \lambda x : S . R x y \to R y x$ (appl) on (-23) and (-22)
#     * (-20) $x, y : S, p : R x y \vdash x : S $ (VAR)
#     * (-19) $x, y : S, p : R x y \vdash u y x : R x y \to R y x$ (appl) on (-21) and (-20)
#     * (-18) $x, y : S, p : R x y \vdash p : R x y$ (VAR)
#     * (-17) $x, y : S, p : R x y, t, s : S \vdash v : \Pi x , y, z : S . R x y \to R x z \to R y z$ (VAR)
#     * (-16) $x, y : S, p : R x y, t, s : S \vdash t : S$ (VAR)
#     * (-15) $x, y : S, p : R x y, t, s : S \vdash v t : \Pi x , y : S . R x y \to R x t \to R y t$ (appl) on (-17) and (-16)
#     * (-14) $x, y : S, p : R x y, t, s : S \vdash t : S$ (VAR)
#     * (-13) $x, y : S, p : R x y, t, s : S \vdash v t t : \Pi x : S . R x t \to R x t \to R t t$ (appl) on (-15) and (-14)
#     * (-12) $x, y : S, p : R x y, t, s : S \vdash s : S$ (VAR)
#     * (-11) $x, y : S, p : R x y, t, s : S \vdash v t t s : R s t \to R s t \to R t t$ (appl) on (-13) and (-12)
#     * (-10) $x, y : S, p : R x y \vdash \lambda t, s : S . v t t s : \Pi t, s : S : R s t \to R s t \to R t t$ (abst) on (-11)
#     * (-9) $x, y : S,  \vdash y : S$ (VAR)
#     * (-8) $x, y : S, p : R x y \vdash (\lambda t, s : S . v t t s) y : \Pi t : S : R y t \to R y t \to R t t$ (appl) on (-10) and (-9)
#     * (-7) $x, y : S, p : R x y \vdash x : S$ (VAR)
#     * (-6) $x, y : S, p : R x y \vdash (\lambda t, s : S . v t t s) y x : R y x \to R y x \to R x x$ (appl) on (-8) and (-7)
#     * (-5) $x, y : S, p : R x y \vdash u y x p : R y x$ (appl) on (-19) and (-18)
#     * (-4) $x, y : S, p : R x y \vdash (\lambda t, s : S . v t t s) y x (u y x p) : R y x \to R x x$ (appl) on (-6) and (-5)
#     * (-3) $x, y : S, p : R x y \vdash u y x p : R y x$ (appl) on (-19) and (-18)
#     * (-2) $x, y : S, p : R x y \vdash (\lambda t, s : S . v t t s) y x (u y x p) (u y x p) : R x x$ (appl) on (-4) and (-3)
#     * (-1) $x, y : S \vdash \lambda p : R x y . (\lambda t, s : S . v t t s) y x (u y x p) (u y x p) : R x y \to R x x$ (abst) on (-2)
#     * (0) $\vdash \lambda x, y : S . \lambda p : R x y . (\lambda t, s : S . v t t s) y x (u y x p) (u y x p) : \Pi x, y : S . R x y \to R x x$ (abst) on (-1)
#
#     * (-18) $x, y, z : S, p : R x y, q : R y z, r, s, t : S \vdash v : R x y \to R x z \to R y z$ (VAR)
#     * (-17) $x, y, z : S, p : R x y, q : R y z, r, s, t : S \vdash r, s, t : S$ (VAR)
#     * (-16) $x, y, z : S, p : R x y, q : R y z \vdash u: \lambda x, y : S . R x y \to R y x$ (VAR)
#     * (-15) $x, y, z : S, p : R x y, q : R y z \vdash y: S$ (VAR)
#     * (-14) $x, y, z : S, p : R x y, q : R y z, r, s, t : S \vdash v r s t : R r s \to R r t \to R s t$ (appl) on (-18) and (-17)
#     * (-13) $x, y, z : S, p : R x y, q : R y z \vdash u y: \lambda x : S . R x y \to R y x$ (appl) on (-16) and (-15)
#     * (-12) $x, y, z : S, p : R x y, q : R y z \vdash x: S$ (VAR)
#     * (-11) $x, y, z : S, p : R x y, q : R y z \vdash \lambda r, s, t : S . v r s t: R r s \to R r t \to R s t$ (abst) on (-14)
#     * (-10) $x, y, z : S, p : R x y, q : R y z \vdash x, y, z: S$ (VAR)
#     * (-9) $x, y, z : S, p : R x y, q : R y z \vdash u y x: R x y \to R y x$ (appl) on (-13) and (-12)
#     * (-8) $x, y, z : S, p : R x y, q : R y z \vdash p: R x y$ (VAR)
#     * (-7) $x, y, z : S, p : R x y, q : R y z \vdash (\lambda r, s, t : S . v r s t) y x z: R y x \to R y z \to R x z$ (appl) on (-11) and (-10)
#     * (-6) $x, y, z : S, p : R x y, q : R y z \vdash u y x p: R y x$ (appl) on (-9) and (-8)
#     * (-5) $x, y, z : S, p : R x y, q : R y z \vdash ((\lambda r, s, t : S . v r s t) y x z) (u y x p): R y z \to R x z$ (appl) on (-7) and (-6)
#     * (-4) $x, y, z : S, p : R x y, q : R y z \vdash q: R y z$ (VAR)
#     * (-3) $x, y, z : S, p : R x y, q : R y z \vdash ((\lambda r, s, t : S . v r s t) y x z) (u y x p) q: R x z$ (appl) on (-5) and (-4)
#     * (-2) $x, y, z : S, p : R x y \vdash \lambda q : R y z . ((\lambda r, s, t : S . v r s t) y x z) (u y x p) q : R y z \to R x z$ (abst) on (-3)
#     * (-1) $x, y, z : S \vdash \lambda p : R x y . (\lambda q : R y z . ((\lambda r, s, t : S . v r s t) y x z) (u y x p) q) : R x y \to R y z \to R x z$ (abst) on (-2)
#     * (0) $\vdash \lambda x, y, z : S . (\lambda p : R x y . (\lambda q : R y z . ((\lambda r, s, t : S . v r s t) y x z) (u y x p) q)) : \Pi x, y, z : S . R x y \to R y z \to R x z$ (abst) on (-1)
#
# * Watch "Propositions as types" by Phil Wadler (a bit over 40 minutes in total). It is worth it.
